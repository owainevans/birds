# %%
with open('moves.dat','r') as f:
    moves = f.read()

# %%
movesd = eval(moves)

# %%
move=movesd

# %%
# %run train_birds.py
# Out:
# Using 2 particles
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:923: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   if warn: warnings.warn(_use_error_msg)

# %%
allMoves = checkMoves(move)
# Out:
# allMoves total for day 0: 1007
# allMoves total for day 1: 1014
# allMoves total for day 2: 983
# allMoves total for day 3: 1000
# allMoves total for day 4: 989

# %%
plt.imshow?

# %%
day0 = allMoves[0]

# %%
fig,ax = plt.subplots(5,1,figsize=(14,19) )
[ax[i].plot(allMoves[i]) for i in range(5)]
# Out:
# [[<matplotlib.lines.Line2D at 0xbc23c4c>],
# ...

# %%
with open('recon2.csv','r') as f:
    recon = f.read()
    
cd ~/birds/eval
# Out:
#   File "<ipython-input-22-2c67f4e8a555>", line 4
#     cd ~/birds/eval
#        ^
# SyntaxError: invalid syntax

# %%
cd /home/owainevans/birds/eval
# Out:
# /home/owainevans/birds/eval

# %%
# %run birdcast_eval.py

# %%
out = read_reconstruction_csv('/home/owainevans/birds/recon2.csv')

# %%
out?
