# %%
cd ~/birds
# Out:
# /home/owainevans/birds

# %%
# %run plotMoves.py

# %%
path = 'getMoves_8043/'
# 1000 transitions and 1 iteration
allMoves,allMovesGround,fig = plotMoves(path)
# Out:
# allMoves total for day 0: 1022
# allMoves total for day 1: 1044
# allMoves total for day 2: 1039
# allMoves total for day 3: 1020
# allMoves total for day 4: 1009
# allMoves total for day 5: 1017
# allMoves total for day 6: 1011
# allMoves total for day 7: 1026
# allMoves total for day 8: 1074
# allMoves total for day 9: 1042
# allMoves total for day 10: 985
# allMoves total for day 11: 971
# allMoves total for day 12: 1001
# allMoves total for day 13: 972
# allMoves total for day 14: 956
# allMoves total for day 15: 960
# allMoves total for day 16: 993
# allMoves total for day 17: 952
# allMoves total for day 0: 1000
# allMoves total for day 1: 1000
# allMoves total for day 2: 1000
# allMoves total for day 3: 1000
# allMoves total for day 4: 1000
# allMoves total for day 5: 1000
# allMoves total for day 6: 1000
# allMoves total for day 7: 1000
# allMoves total for day 8: 1000
# allMoves total for day 9: 1000
# allMoves total for day 10: 1000
# allMoves total for day 11: 1000
# allMoves total for day 12: 1000
# allMoves total for day 13: 1000
# allMoves total for day 14: 1000
# allMoves total for day 15: 1000
# allMoves total for day 16: 1000
# allMoves total for day 17: 1000
# allMoves total for day 18: 1000

# %%
no_days=19
#fig,ax = plt.subplots(no_days,1,figsize=(10,3*no_days) )
#[ax[i].plot(allMovesGround[i]) for i in range(no_days)];

# %%
plotSamples(path,noIters=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-97b3a08163a7> in <module>()
# ----> 1 plotSamples(path,noIters=1)
#
# /home/owainevans/birds/plotMoves.py in plotSamples(baseDirectory, noIters)
#      53     ax[0].hist(l2,label='L2_post')
#      54     ax[1].hist(l2Prior,label='L2_prior',color='green')
# ---> 55     ax.legend()
#      56
#      57     fig,ax = plt.subplots()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'legend'
